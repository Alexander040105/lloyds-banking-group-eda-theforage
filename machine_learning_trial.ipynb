# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import warnings
import numpy as np 
import plotly.express as px
import os
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
current_directory = os.getcwd()
churn_data = pd.read_csv(f'{current_directory}\\customer_churn_analysis_cleaned.csv')
churn_data
# Out:
#      CustomerID  Age FirstTransactionDate LastTransactionDate  \
# 0             1   62           2022-03-27          2022-03-27
# 1             2   65           2022-01-09          2022-11-19
# 2             3   18           2022-02-11          2022-10-08
# 3             4   21           2022-05-22          2022-12-27
# 4             5   21           2022-02-21          2022-12-21
# ..          ...  ...                  ...                 ...
# 995         996   54           2022-07-24          2022-07-24
# 996         997   19           2022-08-06          2022-10-25
# 997         998   47           2022-09-18          2022-09-18
# 998         999   23           2022-01-20          2022-12-07
# 999        1000   34           2022-04-08          2022-12-13
#
#      TotalAmountSpent FirstInteractionDate  LastInteractionDate  \
# 0              416.50  2022-03-31 00:00:00  2022-03-31 00:00:00
# 1             1547.42  2022-03-17 00:00:00  2022-03-17 00:00:00
# ...

# %%
churn_data.drop(columns=['CustomerID', 'FirstTransactionDate', 'LastTransactionDate', 'FirstInteractionDate', 'LastInteractionDate'], inplace=True)

X = churn_data.drop(columns=['ChurnStatus', 'LastLoginDate', 'AgeGroup'])
y = churn_data['ChurnStatus']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

y_pred = rf_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:\n", classification_rep)

sample = X_test.sample(n=5, random_state=42) 
predictions = rf_classifier.predict(sample)

for i, (idx, row) in enumerate(sample.iterrows()):
    print(f"\nSample Customer (index {idx}): {row.to_dict()}")
    print(f"Predicted Churn Status: {'Not Churned' if predictions[i] == 0 else 'Churned'}")
# Out:
# Accuracy: 0.75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86       190
#            1       0.25      0.02      0.03        60
#
#     accuracy                           0.75       250
#    macro avg       0.51      0.50      0.44       250
# weighted avg       0.64      0.75      0.66       250
#
#
# Sample Customer (index 721): {'Age': 43, 'TotalAmountSpent': 814.74, 'TotalServiceInteractions': 1.0, 'LoginFrequency': 25, 'TransactionCount': 3, 'MaritalStatus_Divorced': True, 'MaritalStatus_Married': False, 'MaritalStatus_Single': False, 'MaritalStatus_Widowed': False, 'Gender_F': True, 'Gender_M': False, 'IncomeLevel_High': True, 'IncomeLevel_Low': False, 'IncomeLevel_Medium': False, 'ServiceUsage_Mobile App': False, 'ServiceUsage_Online Banking': False, 'ServiceUsage_Website': True}
# Predicted Churn Status: Not Churned
#
# ...
